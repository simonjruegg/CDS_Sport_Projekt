# %%
from datareader import load_data
import pandas as pd

data = load_data('20251010_Schilthorn_HIM_3A_CS_RI_GNSS Kopie.csv')

# convert to DataFrame for easier handling
df = pd.DataFrame([x.split(',') for x in data.split('\n')])
# Out:
#                 0               1               2                3  \
# 0  time [POSIXms]  timestamp [us]  latitude [deg]  longitude [deg]
# 1   1760082114000         1309250      46.5639795         7.852534
# 2   1760082114266         1437750      46.5639795         7.852534
# 3   1760082114400         1513750      46.5639795         7.852534
# 4   1760082114500         1614000      46.5639795         7.852534
#
#               4             5             6             7
# 0  speedN [m/s]  speedE [m/s]  speedD [m/s]  altitude [m]
# 1             0             0             0      2520.333
# 2             0             0             0      2520.333
# 3             0             0             0      2520.333
# 4             0             0             0      2520.333
